# %%
import sys
import seaborn
import matplotlib.pyplot as plt

sys.path.insert(0, './src/')

import af_analysis
from af_analysis import analysis
from af_analysis import docking
#from af_analysis import clustering
print(af_analysis.__file__)
# Out:
# /home/murail/Documents/Code/af_analysis/./src/af_analysis/__init__.py

# %%
# %matplotlib inline

# %% [markdown]
# ## Importing Data

# %%
my_data = af_analysis.Data('./src/af_analysis/test/inputs/beta_amyloid_dimer_cf_1.5.5/', verbose=False)

# %%
my_data.df
# Out:
#                          query  seed  model                  weight  recycle  \
# 0   beta_amyloid_dimer_d2fa3_0     0      1  alphafold2_multimer_v3        9
# 1   beta_amyloid_dimer_d2fa3_0     0      2  alphafold2_multimer_v3       16
# 2   beta_amyloid_dimer_d2fa3_0     0      3  alphafold2_multimer_v3        3
# 3   beta_amyloid_dimer_d2fa3_0     0      4  alphafold2_multimer_v3        5
# 4   beta_amyloid_dimer_d2fa3_0     0      5  alphafold2_multimer_v3        5
# 5   beta_amyloid_dimer_d2fa3_0     1      1  alphafold2_multimer_v3       14
# 6   beta_amyloid_dimer_d2fa3_0     1      2  alphafold2_multimer_v3       15
# 7   beta_amyloid_dimer_d2fa3_0     1      3  alphafold2_multimer_v3       15
# 8   beta_amyloid_dimer_d2fa3_0     1      4  alphafold2_multimer_v3       48
# 9   beta_amyloid_dimer_d2fa3_0     1      5  alphafold2_multimer_v3       12
# 10  beta_amyloid_dimer_d2fa3_0     2      1  alphafold2_multimer_v3        7
# 11  beta_amyloid_dimer_d2fa3_0     2      2  alphafold2_multimer_v3       14
# 12  beta_amyloid_dimer_d2fa3_0     2      3  alphafold2_multimer_v3        7
# 13  beta_amyloid_dimer_d2fa3_0     2      4  alphafold2_multimer_v3        8
# 14  beta_amyloid_dimer_d2fa3_0     2      5  alphafold2_multimer_v3        9
# 15  beta_amyloid_dimer_d2fa3_0     3      1  alphafold2_multimer_v3        4
# 16  beta_amyloid_dimer_d2fa3_0     3      2  alphafold2_multimer_v3       18
# 17  beta_amyloid_dimer_d2fa3_0     3      3  alphafold2_multimer_v3        6
# 18  beta_amyloid_dimer_d2fa3_0     3      4  alphafold2_multimer_v3       10
# 19  beta_amyloid_dimer_d2fa3_0     3      5  alphafold2_multimer_v3        8
# 20  beta_amyloid_dimer_d2fa3_0     4      1  alphafold2_multimer_v3       11
# 21  beta_amyloid_dimer_d2fa3_0     4      2  alphafold2_multimer_v3       14
# 22  beta_amyloid_dimer_d2fa3_0     4      3  alphafold2_multimer_v3        7
# 23  beta_amyloid_dimer_d2fa3_0     4      4  alphafold2_multimer_v3       11
# 24  beta_amyloid_dimer_d2fa3_0     4      5  alphafold2_multimer_v3        9
# 25  beta_amyloid_dimer_d2fa3_0     5      1  alphafold2_multimer_v3       11
# 26  beta_amyloid_dimer_d2fa3_0     5      2  alphafold2_multimer_v3        7
# 27  beta_amyloid_dimer_d2fa3_0     5      3  alphafold2_multimer_v3        7
# 28  beta_amyloid_dimer_d2fa3_0     5      4  alphafold2_multimer_v3       19
# 31   35.2  0.131  0.0683             0.08084  colabfold_1.5
# 32   44.0  0.235  0.1510             0.16780  colabfold_1.5
# 33   52.6  0.345  0.2740             0.28820  colabfold_1.5
# 34   66.7  0.610  0.5840             0.58920  colabfold_1.5
# 35   38.0  0.146  0.0776             0.09128  colabfold_1.5
# 36   35.2  0.132  0.0693             0.08184  colabfold_1.5
# 37   44.2  0.227  0.1400             0.15740  colabfold_1.5
# 38   47.8  0.273  0.1990             0.21380  colabfold_1.5
# 39   67.4  0.620  0.5980             0.60240  colabfold_1.5
#
#                                                   pdb  \
# 0   ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 1   ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 2   ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 3   ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 4   ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 5   ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 6   ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 7   ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 8   ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 9   ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 10  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 11  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 12  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 13  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 14  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 15  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 16  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 17  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 18  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 19  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 20  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 21  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 22  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 23  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 24  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 25  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 26  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 27  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 28  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 29  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 30  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 31  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 32  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 33  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 34  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 35  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 36  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 37  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 38  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 39  ./src/af_analysis/test/inputs/beta_amyloid_dim...
#
#                                           relaxed_pdb  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39  ./src/af_analysis/test/inputs/beta_amyloid_dim...
#
#                                             data_file
# 0   ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 1   ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 2   ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 3   ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 4   ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 5   ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 6   ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 7   ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 8   ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 9   ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 10  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 11  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 12  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 13  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 14  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 15  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 16  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 17  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 18  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 19  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 20  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 21  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 22  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 23  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 24  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 25  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 26  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 27  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 28  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 29  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 30  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 31  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 32  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 33  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 34  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 35  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 36  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 37  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 38  ./src/af_analysis/test/inputs/beta_amyloid_dim...
# 39  ./src/af_analysis/test/inputs/beta_amyloid_dim...

# %%
my_data.plot_msa()

# %% [markdown]
# ## Interactive ploting

# %%
import numpy as np
np.cumsum(my_data.chain_length['beta_amyloid_dimer_d2fa3_0'][:-1])
# Out:
# array([42])

# %%
my_data.show_plot_info()
# Out:
# IntSlider(value=1, description='model:', max=40, min=1)
# Output(layout=Layout(width='95%'))

# %%
my_data.plot_plddt()
plt.savefig('docs/source/_static/plddt_amyloid.png')

# %%
my_data.plot_plddt([0,1])
plt.savefig('docs/source/_static/plddt_amyloid_sel.png')

# %%
my_data.chain_length
# Out:
# {'beta_amyloid_dimer_d2fa3_0': [42, 42]}

# %%
best_model_index = my_data.df['ranking_confidence'].idxmax()
my_data.plot_pae(best_model_index)
plt.savefig('docs/source/_static/PAE_amyloid_best.png')

# %% [markdown]
# ## Several analysis

# %%
my_data.df.columns
# Out:
# Index(['query', 'seed', 'model', 'weight', 'recycle', 'pLDDT', 'pTM', 'ipTM',
#        'ranking_confidence', 'format', 'pdb', 'relaxed_pdb', 'json'],
#       dtype='object')

# %%
docking.pae_pep(my_data, verbose=False)

my_data.df.columns
# Out:
# Index(['query', 'seed', 'model', 'weight', 'recycle', 'pLDDT', 'pTM', 'ipTM',
#        'ranking_confidence', 'format', 'pdb', 'relaxed_pdb', 'json',
#        'PAE_pep_rec', 'PAE_rec_pep'],
#       dtype='object')

# %%
docking.plddt_pep(my_data, verbose=False)
my_data.df.columns
# Out:
# Index(['query', 'seed', 'model', 'weight', 'recycle', 'pLDDT', 'pTM', 'ipTM',
#        'ranking_confidence', 'format', 'pdb', 'relaxed_pdb', 'json',
#        'PAE_pep_rec', 'PAE_rec_pep', 'plddt_pep'],
#       dtype='object')

# %%
docking.LIS_pep(my_data, verbose=False)
my_data.df.columns
# Out:
# Index(['query', 'seed', 'model', 'weight', 'recycle', 'pLDDT', 'pTM', 'ipTM',
#        'ranking_confidence', 'format', 'pdb', 'relaxed_pdb', 'json',
#        'PAE_pep_rec', 'PAE_rec_pep', 'plddt_pep', 'LIS', 'LIS_rec_pep',
#        'LIS_pep_rec'],
#       dtype='object')

# %%
docking.pdockq2_lig(my_data, verbose=False)
my_data.df.columns
# Out:
# Index(['query', 'seed', 'model', 'weight', 'recycle', 'pLDDT', 'pTM', 'ipTM',
#        'ranking_confidence', 'format', 'pdb', 'relaxed_pdb', 'json',
#        'PAE_pep_rec', 'PAE_rec_pep', 'plddt_pep', 'LIS', 'LIS_rec_pep',
#        'LIS_pep_rec', 'pdockq2_A', 'pdockq2_B', 'pdockq2_lig'],
#       dtype='object')

# %%
my_data.df.head(2)
# Out:
#                         query  seed  model                  weight  recycle  \
# 0  beta_amyloid_dimer_d2fa3_0     0      1  alphafold2_multimer_v3        9
# 1  beta_amyloid_dimer_d2fa3_0     0      2  alphafold2_multimer_v3       16
#
#    pLDDT    pTM    ipTM  ranking_confidence         format  ...  \
# 0   38.8  0.159  0.0812             0.09676  colabfold_1.5  ...
# 1   35.2  0.130  0.0685             0.08080  colabfold_1.5  ...
#
#                                                 json PAE_pep_rec PAE_rec_pep  \
# 0  ./src/af_analysis/test/inputs/beta_amyloid_dim...   21.026196   20.984252
# 1  ./src/af_analysis/test/inputs/beta_amyloid_dim...   22.760130   22.746667
#
#    plddt_pep                                                LIS  LIS_rec_pep  \
# 0  38.685476  [[0.44785182119205297, 0.11038825757575756], [...     0.107481
# 1  34.902857  [[0.4598769470404984, 0.10359090909090911], [0...     0.103333
#
#   LIS_pep_rec  pdockq2_A  pdockq2_B  pdockq2_lig
# 0    0.110388   0.012064   0.011992     0.011992
# 1    0.103591   0.010768   0.010624     0.010624
#
# [2 rows x 22 columns]

# %%
# Compute pdockq
analysis.pdockq(my_data, verbose=False)
# Compute pdockq2
analysis.pdockq2(my_data, verbose=False)

#extract_pae_pep
docking.pae_pep(my_data, verbose=False)
#compute_pdockq2_lig
docking.pdockq2_lig(my_data, verbose=False)
#compute_LIS_pep
docking.LIS_pep(my_data, verbose=False)
#extract_plddt_pep
docking.plddt_pep(my_data, verbose=False)

# %% [markdown]
# ## Clustering

# %%
clustering.hierarchical(my_data.df, threshold=4)
# Out:
# /home/murail/miniforge3/envs/SST2/lib/python3.12/site-packages/MDAnalysis/coordinates/base.py:728: UserWarning: Reader has no dt information, set to 1.0 ps
#   return self.ts.dt
#   0%|          | 0/40 [00:00<?, ?it/s]
#   0%|          | 0/40 [00:00<?, ?it/s]

# %%
my_data.df
# Out:
#                          query  seed  model                  weight  recycle  \
# 0   beta_amyloid_dimer_d2fa3_0     0      1  alphafold2_multimer_v3        9
# 1   beta_amyloid_dimer_d2fa3_0     0      2  alphafold2_multimer_v3       16
# 2   beta_amyloid_dimer_d2fa3_0     0      3  alphafold2_multimer_v3        3
# 3   beta_amyloid_dimer_d2fa3_0     0      4  alphafold2_multimer_v3        5
# 4   beta_amyloid_dimer_d2fa3_0     0      5  alphafold2_multimer_v3        5
# 5   beta_amyloid_dimer_d2fa3_0     1      1  alphafold2_multimer_v3       14
# 6   beta_amyloid_dimer_d2fa3_0     1      2  alphafold2_multimer_v3       15
# 7   beta_amyloid_dimer_d2fa3_0     1      3  alphafold2_multimer_v3       15
# 8   beta_amyloid_dimer_d2fa3_0     1      4  alphafold2_multimer_v3       48
# 9   beta_amyloid_dimer_d2fa3_0     1      5  alphafold2_multimer_v3       12
# 10  beta_amyloid_dimer_d2fa3_0     2      1  alphafold2_multimer_v3        7
# 11  beta_amyloid_dimer_d2fa3_0     2      2  alphafold2_multimer_v3       14
# 12  beta_amyloid_dimer_d2fa3_0     2      3  alphafold2_multimer_v3        7
# 13  beta_amyloid_dimer_d2fa3_0     2      4  alphafold2_multimer_v3        8
# 14  beta_amyloid_dimer_d2fa3_0     2      5  alphafold2_multimer_v3        9
# 15  beta_amyloid_dimer_d2fa3_0     3      1  alphafold2_multimer_v3        4
# 16  beta_amyloid_dimer_d2fa3_0     3      2  alphafold2_multimer_v3       18
# 17  beta_amyloid_dimer_d2fa3_0     3      3  alphafold2_multimer_v3        6
# 18  beta_amyloid_dimer_d2fa3_0     3      4  alphafold2_multimer_v3       10
# 19  beta_amyloid_dimer_d2fa3_0     3      5  alphafold2_multimer_v3        8
# 20  beta_amyloid_dimer_d2fa3_0     4      1  alphafold2_multimer_v3       11
# 21  beta_amyloid_dimer_d2fa3_0     4      2  alphafold2_multimer_v3       14
# 22  beta_amyloid_dimer_d2fa3_0     4      3  alphafold2_multimer_v3        7
# 23  beta_amyloid_dimer_d2fa3_0     4      4  alphafold2_multimer_v3       11
# 24  beta_amyloid_dimer_d2fa3_0     4      5  alphafold2_multimer_v3        9
# 25  beta_amyloid_dimer_d2fa3_0     5      1  alphafold2_multimer_v3       11
# 26  beta_amyloid_dimer_d2fa3_0     5      2  alphafold2_multimer_v3        7
# 27  beta_amyloid_dimer_d2fa3_0     5      3  alphafold2_multimer_v3        7
# 28  beta_amyloid_dimer_d2fa3_0     5      4  alphafold2_multimer_v3       19
# 29  beta_amyloid_dimer_d2fa3_0     5      5  alphafold2_multimer_v3        9
# 30  beta_amyloid_dimer_d2fa3_0     6      1  alphafold2_multimer_v3       30
# 31  beta_amyloid_dimer_d2fa3_0     6      2  alphafold2_multimer_v3        7
# 32  beta_amyloid_dimer_d2fa3_0     6      3  alphafold2_multimer_v3        5
# 33  beta_amyloid_dimer_d2fa3_0     6      4  alphafold2_multimer_v3        9
# 33   0.042369   0.044225     0.044225  0.050850        1  6.104746  -2.248794
# 34   0.196251   0.190226     0.190226  0.139161        1  6.807828  -3.759404
# 35   0.012358   0.012475     0.012475  0.029403        4 -9.507634  -0.141312
# 36   0.010877   0.010781     0.010781  0.020625        3 -6.086458   7.683419
# 37   0.012640   0.012577     0.012577  0.025423        2  3.870167  -4.387683
# 38   0.022622   0.022912     0.022912  0.036225        1  5.637601  -2.299299
# 39   0.204028   0.205439     0.205439  0.142574        1  6.477445  -3.241368
#
# [40 rows x 26 columns]

# %% [markdown]
# ## LIS Score example

# %%
my_data_2 = af_analysis.Data('./src/af_analysis/test/inputs/fold_2024_07_01_12_14_prot_dna_zn/', verbose=False)

# %%
analysis.LIS_matrix(my_data_2, pae_cutoff=12.0)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
import seaborn as sns
from cmcrameri import cm

ax = sns.heatmap(my_data_2.df.LIS.iloc[0], cmap=cm.roma)
ax.collections[0].set_clim(0,1)  
ax.set_title('LIS heatmap among subunits')
ax.set_xlabel('Subunit index')
ax.set_ylabel('Subunit index')

plt.savefig('docs/source/_static/LIS_prot_dna_zn.png')

# %%
for col in ['LIS_rec_pep', 'LIS_pep_rec']:
    print(my_data.df.iloc[0][col])
# Out:
# 0.10748148148148148
# 0.11038825757575756

# %%
my_data.df.iloc[0]['LIS']
# Out:
# [[0.44785182119205297, 0.11038825757575756],
#  [0.10748148148148148, 0.44471074380165293]]

# %% [markdown]
# Here is the PAE matrix used for calculation

# %%
my_data.plot_pae(0)
# Out:
# (<Figure size 640x480 with 2 Axes>, <Axes: >)

# %% [markdown]
# And here the mask to compute the LIS value based on the PAE matrix.

# %%
from cmcrameri import cm
import numpy as np
import matplotlib.pyplot as plt

pae_cutoff=12.0
index = 0

row = my_data.df.iloc[index]
res_max = sum(my_data.chain_length[row["query"]])
pae_array = af_analysis.data.get_pae(my_data.df.iloc[index]['json'])

img = plt.imshow(
    pae_array > pae_cutoff,
    vmin=0.0,
    vmax=1.0,
)


plt.hlines(
    np.cumsum(my_data.chain_length[row["query"]][:-1]) - 0.5,
    xmin=-0.5,
    xmax=res_max,
    colors="black",
)

plt.vlines(
    np.cumsum(my_data.chain_length[row["query"]][:-1]) - 0.5,
    ymin=-0.5,
    ymax=res_max,
    colors="black",
)

plt.xlim(-0.5, res_max - 0.5)
plt.ylim(res_max - 0.5, -0.5)
# Out:
# (83.5, -0.5)

# %%
import pdb_numpy
# Custom analysis
# Here we compute the number of contacts in the interface
def contact_number(pdb, cutoff=8.0):
    # Compute the number of contacts in the interface
    coor = pdb_numpy.Coor(pdb)
    chains = np.unique(coor.chain)
    contact_num = 0

    for chain in chains:
        coor_interface = coor.select_atoms(f"name CA and chain {chain} and within {cutoff} of not chain {chain}")
        contact_num += coor_interface.len
    
    return contact_num

# %%
contact_list = []
for pdb in my_data.df.pdb:
    contact_list.append(contact_number(pdb))
# Add the contact number to the dataframe
my_data.df['contact_num'] = contact_list
